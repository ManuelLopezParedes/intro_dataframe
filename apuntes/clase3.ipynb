# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelLopezParedes/intro_dataframe/blob/master/apuntes/clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dr_df = pd.read_csv("drinks.csv")

# %% [markdown]
# # entorno de ejecucion de shel de linux
# Para ejecutar un comando en el shell de bes usar el operador de exclamacion de la siguiente forma
# ```!ls-la```

# %%
# !ls drinks*
# Out:
# drinks.csv  drinks.json  drinks.txt  drinks.xlsx  drinks.xml

# %%
dr_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             NaN
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
# !pip list | grep xl
# Out:
# jaxlib                                0.5.1
# openpyxl                              3.1.5
# xlrd                                  2.0.1

# %%
df_excel = pd.read_excel('drinks.xlsx', sheet_name='drinks')
df_excel
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             NaN
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %% [markdown]
# # Manejo basico de DataFrames

# %%
dr_df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     178.000000       170.000000     162.000000
# mean      102.870787        80.835294      50.746914
# std       100.645713        87.993322      76.134917
# min         1.000000         1.000000       1.000000
# 25%        21.000000        11.000000       3.000000
# 50%        60.000000        48.500000      11.500000
# 75%       172.500000       127.500000      61.250000
# max       376.000000       438.000000     339.000000
#
#        total_litres_of_pure_alcohol
# count                    180.000000
# mean                       4.357778
# std                        3.454136
# min                        0.100000
# 25%                        1.375000
# 50%                        3.850000
# 75%                        6.700000
# max                       14.400000

# %% [markdown]
# ### Agregar una columna a un DataFrame

# %%
# agregar columna con un escalar
dr_df['vino_media'] = 50.76
dr_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media
# 0                             NaN       50.76
# 1                             4.9       50.76
# 2                             0.7       50.76
# ...

# %%
# agregar columna con datos diferentes
import random
dr_df['vino_media_random'] = [random.randint(45,60) for x in range (193) ] # list comprehensions
dr_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random
# 0                             NaN       50.76                 56
# 1                             4.9       50.76                 57
# ...

# %% [markdown]
# ### insertar con el metodo insert

# %%
dr_df.insert(loc=2, column='demo', value="algo")
dr_df
# Out:
#          country  beer_servings  demo  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN  algo              NaN            NaN
# 1        Albania           89.0  algo            132.0           54.0
# 2        Algeria           25.0  algo              NaN           14.0
# 3        Andorra          245.0  algo            138.0          312.0
# 4         Angola          217.0  algo             57.0           45.0
# ..           ...            ...   ...              ...            ...
# 188    Venezuela          333.0  algo              1.0            3.0
# 189      Vietnam          111.0  algo              2.0            1.0
# 190        Yemen            6.0  algo              NaN            NaN
# 191       Zambia           32.0  algo             19.0            4.0
# 192     Zimbabwe           64.0  algo             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random
# ...

# %% [markdown]
# ### A partir de datos de otra columna

# %%
dr_df['mitad'] = dr_df['beer_servings'].div(2)
dr_df
# Out:
#          country  beer_servings  demo  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN  algo              NaN            NaN
# 1        Albania           89.0  algo            132.0           54.0
# 2        Algeria           25.0  algo              NaN           14.0
# 3        Andorra          245.0  algo            138.0          312.0
# 4         Angola          217.0  algo             57.0           45.0
# ..           ...            ...   ...              ...            ...
# 188    Venezuela          333.0  algo              1.0            3.0
# 189      Vietnam          111.0  algo              2.0            1.0
# 190        Yemen            6.0  algo              NaN            NaN
# 191       Zambia           32.0  algo             19.0            4.0
# 192     Zimbabwe           64.0  algo             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# ...

# %% [markdown]
# # Borrar columnas
# Un dataframe maneja el concepto de ejes (AXIS)
#
# donde:
#
# axis=0 ---> Renglon
#
# axis=1 ---> Columna

# %%
dr_df.drop(columns=['demo'], axis=1, inplace=True)
dr_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# 0                             NaN       50.76                 56    NaN
# ...

# %% [markdown]
# # Eliminar filas

# %%
dr_df.drop([0,190], axis=0)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania           89.0            132.0           54.0
# 2              Algeria           25.0              NaN           14.0
# 3              Andorra          245.0            138.0          312.0
# 4               Angola          217.0             57.0           45.0
# 5    Antigua & Barbuda           12.0            128.0           45.0
# ..                 ...            ...              ...            ...
# 187            Vanuatu           21.0             18.0           11.0
# 188          Venezuela          333.0              1.0            3.0
# 189            Vietnam          111.0              2.0            1.0
# 191             Zambia           32.0             19.0            4.0
# 192           Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# ...

# %% [markdown]
# # calues counts en el DF

# %%
gm_df = pd.read_csv('games.csv')
gm_df
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
gm_df['Platform'].value_counts()
# Out:
# Platform
# PS3     1329
# X360    1265
# PS4      336
# XOne     213
# Name: count, dtype: int64

# %%
gm_df['Platform'].value_counts(normalize=True)*100
# Out:
# Platform
# PS3     42.284442
# X360    40.248171
# PS4     10.690423
# XOne     6.776965
# Name: proportion, dtype: float64

# %%
gm_df['Platform'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='Platform'>

# %% [markdown]
# ### Eliminar valores vacios NaN
# dropna()

# %%
dr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 178 non-null    float64
#  2   spirit_servings               170 non-null    float64
#  3   wine_servings                 162 non-null    float64
#  4   total_litres_of_pure_alcohol  180 non-null    float64
#  5   vino_media                    193 non-null    float64
#  6   vino_media_random             193 non-null    int64
#  7   mitad                         178 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 12.2+ KB

# %%
dr_df.dropna() # falta el inplace para que el cambio sea permanente
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania           89.0            132.0           54.0
# 3              Andorra          245.0            138.0          312.0
# 4               Angola          217.0             57.0           45.0
# 5    Antigua & Barbuda           12.0            128.0           45.0
# 6            Argentina          193.0             25.0          221.0
# ..                 ...            ...              ...            ...
# 187            Vanuatu           21.0             18.0           11.0
# 188          Venezuela          333.0              1.0            3.0
# 189            Vietnam          111.0              2.0            1.0
# 191             Zambia           32.0             19.0            4.0
# 192           Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# ...

# %%
dr_df.dropna(how='all')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# 0                             NaN       50.76                 56    NaN
# ...

# %%
dr_df.drop(['vino_media','vino_media_random'], axis=1)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  mitad
# 0                             NaN    NaN
# 1                             4.9   44.5
# 2                             0.7   12.5
# ...

# %% [markdown]
# # Completar valores faltantes

# %%
dr_df.fillna(0)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  vino_media  vino_media_random  mitad
# 0                             0.0       50.76                 56    0.0
# ...

# %%
dr_df['beer_servings'].fillna(dr_df['beer_servings'].mean())
# Out:
# 0      102.870787
# 1       89.000000
# 2       25.000000
# 3      245.000000
# 4      217.000000
#           ...
# 188    333.000000
# 189    111.000000
# 190      6.000000
# 191     32.000000
# 192     64.000000
# Name: beer_servings, Length: 193, dtype: float64

# %% [markdown]
# # Ordenar alfabeticamente

# %%
gm_df.sort_values(by='Name', ascending=False)
# Out:
#                                                    Name Platform    Year  \
# 3005                       uDraw Studio: Instant Artist     X360  2011.0
# 207                           pro evolution soccer 2011      PS3  2010.0
# 963                           pro evolution soccer 2011     X360  2010.0
# 2365                                             nail'd     X360  2010.0
# 2234                                             nail'd      PS3  2010.0
# ...                                                 ...      ...     ...
# 2255  2 in 1 Combo Pack: Sonic Heroes / Super Monkey...     X360  2013.0
# 2937                                  11eyes: CrossOver     X360  2009.0
# 382                              007: Quantum of Solace     X360  2008.0
# 503                              007: Quantum of Solace      PS3  2008.0
# 2850                  .hack: Sekai no Mukou ni + Versus      PS3  2012.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Ordenar por mas de una columna

# %%
gm_df.sort_values(by=['Name','Platform'],ascending=True)
# Out:
#                                                    Name Platform    Year  \
# 2850                  .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 503                              007: Quantum of Solace      PS3  2008.0
# 382                              007: Quantum of Solace     X360  2008.0
# 2937                                  11eyes: CrossOver     X360  2009.0
# 2255  2 in 1 Combo Pack: Sonic Heroes / Super Monkey...     X360  2013.0
# ...                                                 ...      ...     ...
# 2234                                             nail'd      PS3  2010.0
# 2365                                             nail'd     X360  2010.0
# 207                           pro evolution soccer 2011      PS3  2010.0
# 963                           pro evolution soccer 2011     X360  2010.0
# 3005                       uDraw Studio: Instant Artist     X360  2011.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gm_df.sort_values(by=['Name','Platform'],ascending=[True,False])
# Out:
#                                                    Name Platform    Year  \
# 2850                  .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 382                              007: Quantum of Solace     X360  2008.0
# 503                              007: Quantum of Solace      PS3  2008.0
# 2937                                  11eyes: CrossOver     X360  2009.0
# 2255  2 in 1 Combo Pack: Sonic Heroes / Super Monkey...     X360  2013.0
# ...                                                 ...      ...     ...
# 2365                                             nail'd     X360  2010.0
# 2234                                             nail'd      PS3  2010.0
# 963                           pro evolution soccer 2011     X360  2010.0
# 207                           pro evolution soccer 2011      PS3  2010.0
# 3005                       uDraw Studio: Instant Artist     X360  2011.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Ordenar por incie

# %%
gm_df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df_sort = gm_df.sort_values(['Name','Platform'])
df_sort
# Out:
#                                                    Name Platform    Year  \
# 2850                  .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 503                              007: Quantum of Solace      PS3  2008.0
# 382                              007: Quantum of Solace     X360  2008.0
# 2937                                  11eyes: CrossOver     X360  2009.0
# 2255  2 in 1 Combo Pack: Sonic Heroes / Super Monkey...     X360  2013.0
# ...                                                 ...      ...     ...
# 2234                                             nail'd      PS3  2010.0
# 2365                                             nail'd     X360  2010.0
# 207                           pro evolution soccer 2011      PS3  2010.0
# 963                           pro evolution soccer 2011     X360  2010.0
# 3005                       uDraw Studio: Instant Artist     X360  2011.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_sort.sort_index(axis=0,ascending=False)
# Out:
#                                 Name Platform    Year         Genre  \
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# ...                              ...      ...     ...           ...
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 0                 Kinect Adventures!     X360  2010.0          Misc
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 3142    Alternative Software      0.00      0.01      0.00         0.00
# ...

# %% [markdown]
# # Trabajar con indices de renglon y columna

# %%
# Indice de renglones
gm_df.index
# Out:
# RangeIndex(start=0, stop=3143, step=1)

# %%
# Indice de columnas
gm_df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
gm_df.index=pd.RangeIndex(1,3144,1)
gm_df
# Out:
#                                 Name Platform    Year         Genre  \
# 1                 Kinect Adventures!     X360  2010.0          Misc
# 2                 Grand Theft Auto V      PS3  2013.0        Action
# 3                 Grand Theft Auto V     X360  2013.0        Action
# 4     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 5            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3139                  Bound By Flame     X360  2014.0  Role-Playing
# 3140                    Mighty No. 9     XOne  2016.0      Platform
# 3141              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3142   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3143               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...
