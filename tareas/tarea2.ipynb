# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelLopezParedes/intro_dataframe/blob/master/tareas/tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importacion de modulos
import numpy as np
import pandas as pd

# %% [markdown]
# # Necesitamos crear un dataframe a partir de la siguiente tabla
# |Nombre|V1|V2|V3|V4|
# |-----|---|--|--|--|
# |Jose|3984|3612|376|1688|
# |Pedro|1442|1390|4215|2591|
# |Maria|525|2393|2974|208|
# |Juan|599|1492|405|2815|
# |Sebastian|1792|1584|768|3477|
# |Noe|3711|3732|342|4128|
# |Francisco|3151|4213|3588|4874|
# |Tomas|4873|2295|3704|4340|
# |Alejandro|4400|2558|3568|4915|

# %%
# creación de dataframe
data = { # creamos un diccionario para almacenar los valores
    "Nombre" : ["Jose","Pedro","Maria","Juan","Sebastian","Noe","Fransisco","Tomas","Alejandro"],
    "V1" : [3984,1442,525,599,1792,3711,3151,4873,4400],
    "V2" : [3612,1390,2393,1492,1584,3732,4213,2295,2558],
    "V3" : [376,4215,2974,405,768,342,3588,3704,3568],
    "V4" : [1688,2591,208,2815,3477,4128,4874,4340,4915]
        }

df = pd.DataFrame(data)
df
# Out:
#       Nombre    V1    V2    V3    V4
# 0       Jose  3984  3612   376  1688
# 1      Pedro  1442  1390  4215  2591
# 2      Maria   525  2393  2974   208
# 3       Juan   599  1492   405  2815
# 4  Sebastian  1792  1584   768  3477
# 5        Noe  3711  3732   342  4128
# 6  Fransisco  3151  4213  3588  4874
# 7      Tomas  4873  2295  3704  4340
# 8  Alejandro  4400  2558  3568  4915

# %% [markdown]
# # Operaciones:
# - Mostrar la informacion general del DF
# - Mostrar la estadística descriptiva básica.
# - Mostrar las ultimas 10 filas tail()
# - Opcional --> Lo que gustes practicar

# %%
# Mostrar informacion general del DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  9 non-null      object
#  1   V1      9 non-null      int64
#  2   V2      9 non-null      int64
#  3   V3      9 non-null      int64
#  4   V4      9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 492.0+ bytes

# %%
# Mostrar la estadistica descriptiva basica
df.describe()
# Out:
#                 V1           V2           V3           V4
# count     9.000000     9.000000     9.000000     9.000000
# mean   2719.666667  2585.444444  2215.555556  3226.222222
# std    1659.611400  1046.845752  1687.042391  1570.515025
# min     525.000000  1390.000000   342.000000   208.000000
# 25%    1442.000000  1584.000000   405.000000  2591.000000
# 50%    3151.000000  2393.000000  2974.000000  3477.000000
# 75%    3984.000000  3612.000000  3588.000000  4340.000000
# max    4873.000000  4213.000000  4215.000000  4915.000000

# %%
# mostrar ultimas 10 filas
df.tail(10)
# Out:
#       Nombre    V1    V2    V3    V4
# 0       Jose  3984  3612   376  1688
# 1      Pedro  1442  1390  4215  2591
# 2      Maria   525  2393  2974   208
# 3       Juan   599  1492   405  2815
# 4  Sebastian  1792  1584   768  3477
# 5        Noe  3711  3732   342  4128
# 6  Fransisco  3151  4213  3588  4874
# 7      Tomas  4873  2295  3704  4340
# 8  Alejandro  4400  2558  3568  4915

# %%
# filtro de datos
print(df[df['V1']> 1000])
# Out:
#       Nombre    V1    V2    V3    V4
# 0       Jose  3984  3612   376  1688
# 1      Pedro  1442  1390  4215  2591
# 4  Sebastian  1792  1584   768  3477
# 5        Noe  3711  3732   342  4128
# 6  Fransisco  3151  4213  3588  4874
# 7      Tomas  4873  2295  3704  4340
# 8  Alejandro  4400  2558  3568  4915
